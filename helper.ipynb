# %%
import pandas as pd
pd.options.display.max_columns = None

# %%
df = pd.read_csv("/Users/vzw960/Dropbox (GloriamGroup)/PERSONAL/Teaching/PhD-PerMed/PGx-workshop/data/drugLabels_drugbank_full.csv")
# Out:
#    PharmGKB ID                                               Name      Source  \
# 0  PA166184405  Annotation of Swissmedic Label for brexpiprazo...  Swissmedic
# 1  PA166184405  Annotation of Swissmedic Label for brexpiprazo...  Swissmedic
# 2  PA166184405  Annotation of Swissmedic Label for brexpiprazo...  Swissmedic
# 3  PA166184405  Annotation of Swissmedic Label for brexpiprazo...  Swissmedic
# 4  PA166184405  Annotation of Swissmedic Label for brexpiprazo...  Swissmedic
#
#   Biomarker Flag   Testing Level Has Prescribing Info Has Dosing Info  \
# 0            NaN  Actionable PGx     Prescribing Info     Dosing Info
# 1            NaN  Actionable PGx     Prescribing Info     Dosing Info
# 2            NaN  Actionable PGx     Prescribing Info     Dosing Info
# 3            NaN  Actionable PGx     Prescribing Info     Dosing Info
# 4            NaN  Actionable PGx     Prescribing Info     Dosing Info
#
#   Has Alternate Drug Cancer Genome  Prescribing      Chemicals   Genes  \
# ...

# %%
cols = ['PharmGKB ID', 'Name', 'Source', 'Testing Level',
       'Has Prescribing Info', 'Has Dosing Info', 'Has Alternate Drug',
       'Prescribing', 'Chemicals', 'Genes',
       'Variants/Haplotypes', 'type',
       'drugbank_id', 'name', 'indication', 'atc_codes', 'actions', 'pubmed_ids',
       'uniprot', 'EntryName', 'ProteinID', 'ProteinFamily',
       'ProteinSuperFamily']

df[cols].head()

df[cols].to_csv("/Users/vzw960/Dropbox (GloriamGroup)/PERSONAL/Teaching/PhD-PerMed/PGx-workshop/data/drugLabels_drugbank.csv")
